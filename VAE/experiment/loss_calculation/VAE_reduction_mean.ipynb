# %%
import torch
import torch.nn as nn

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter('runs/vae_reduction_mean')

# %%
device = torch.device("cpu")
# for nvidia gpu ( cuda backend )
if (torch.cuda.is_available()):
    device = torch.device("cuda")
  # mps for apple M GPU ( metal backend )
elif (torch.backends.mps.is_available()):
    device = torch.device("mps")

print("Using device:", device)
# Out:
# Using device: mps

# %%
lr = 1e-3
batch_size = 256
epochs = 100

# %%
from torchvision.datasets import MNIST
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

dataset_path = '../data'


mnist_transform = transforms.Compose([
    transforms.ToTensor(),
])

kwargs = {'num_workers': 1, 'pin_memory': True}

train_dataset = MNIST(
    dataset_path, transform=mnist_transform, train=True, download=True)
test_dataset = MNIST(dataset_path, transform=mnist_transform,
                     train=False, download=True)

train_loader = DataLoader(dataset=train_dataset,
                          batch_size=batch_size, shuffle=True, **kwargs)
test_loader = DataLoader(dataset=test_dataset,
                         batch_size=batch_size, shuffle=False, **kwargs)

# %%
import sys # nopep8
sys.path.append('../')  # nopep8
from model import VAE
# from annealing import Annealing




model = VAE(
    encoder= nn.Sequential(
        nn.Linear(784, 512),
        nn.ReLU(),
        nn.Linear(512,256),
        nn.ReLU(),
    ),
    decoder= nn.Sequential(
        nn.Linear(128, 256),
        nn.ReLU(),
        nn.Linear(256, 512),
        nn.ReLU(),
        nn.Linear(512, 784),
        nn.Sigmoid()
    ),
    mean= nn.Linear(256, 128),
    var= nn.Linear(256, 128)
).to(device)


# annealing = Annealing.frange_cycle_linear(0, 1, 100)
# Out:
# VAE model initialized

# %%
from torch.optim import Adam


def loss_function(x, x_hat, mean, log_var):
    # sum over pixels then div by the batch dim
    reproduction_loss = nn.functional.mse_loss(x_hat, x, reduction='mean')
    # sum over the dimensions of the latent space then div by the batch dim
    KLD = torch.mean(-0.5 * torch.sum(1 + log_var - mean **
                     2 - log_var.exp()))
    return reproduction_loss, KLD


optimizer = Adam(model.parameters(), lr=lr)

# %%
print("Start training VAE...")
model.train()

for epoch in range(epochs):
    overall_loss = 0
    overall_rec = 0
    overall_kl = 0
    for batch_idx, (x, _) in enumerate(train_loader):
        batch_size = x.size(0)
        x = x.view(batch_size, 784)
        x = x.to(device)
        optimizer.zero_grad()
        _, mean, log_var,_,x_hat = model(x)
        if batch_idx == 0:
            writer.add_images('input', x[0].view(
                1, 1, 28, 28), epoch+1)
            writer.add_images('reconstruction', x_hat[0].view(
                1, 1, 28, 28), epoch+1)
            
        loss_rec,loss_kld = loss_function(x, x_hat, mean, log_var)
        loss = loss_rec + 1*(loss_kld)
        overall_rec += loss_rec.item()
        overall_kl += loss_kld.item()
        overall_loss += loss.item()
        loss.backward()
        optimizer.step()

    writer.add_scalar('Loss/total', overall_loss / len(train_loader), epoch+1)
    writer.add_scalar('Loss/rec', overall_rec / len(train_loader), epoch+1)
    writer.add_scalar('Loss/kl', overall_kl / len(train_loader), epoch+1)
    print("\tEpoch", epoch + 1, "complete!", "\tAverage Loss: ",
          overall_loss / len(train_loader))

print("Finish!!")
# Out:
# Start training VAE...
# 	Epoch 1 complete! 	Average Loss:  0.9353858226791342
# 	Epoch 2 complete! 	Average Loss:  0.08890062802015467
# 	Epoch 3 complete! 	Average Loss:  0.07425450000991213
# 	Epoch 4 complete! 	Average Loss:  0.07034059499806546
# 	Epoch 5 complete! 	Average Loss:  0.06866289773520003
# 	Epoch 6 complete! 	Average Loss:  0.06815889471388878
# 	Epoch 7 complete! 	Average Loss:  0.06753642498812777
# 	Epoch 8 complete! 	Average Loss:  0.06732306049225179
# 	Epoch 9 complete! 	Average Loss:  0.06737481606133441
# 	Epoch 10 complete! 	Average Loss:  0.06680544078984159
# 	Epoch 11 complete! 	Average Loss:  0.06691267696466852
# 	Epoch 12 complete! 	Average Loss:  0.06713545544350401
# 	Epoch 13 complete! 	Average Loss:  0.06686479664863425
# 	Epoch 14 complete! 	Average Loss:  0.06671663947561954
# 	Epoch 15 complete! 	Average Loss:  0.0667857438959974
# 	Epoch 16 complete! 	Average Loss:  0.06687509642636523
# 	Epoch 17 complete! 	Average Loss:  0.06762545650943796
# 	Epoch 18 complete! 	Average Loss:  0.06668474243042317
# 	Epoch 19 complete! 	Average Loss:  0.06663026055122943
# 	Epoch 20 complete! 	Average Loss:  0.06665282290666662
# 	Epoch 21 complete! 	Average Loss:  0.06676537350137184
# 	Epoch 22 complete! 	Average Loss:  0.0668486568838992
# 	Epoch 23 complete! 	Average Loss:  0.06696535485221984
# 	Epoch 24 complete! 	Average Loss:  0.06665165167539677
# 	Epoch 25 complete! 	Average Loss:  0.06674754898598853
# 	Epoch 26 complete! 	Average Loss:  0.0666029801077031
# 	Epoch 27 complete! 	Average Loss:  0.06658571546382093
# 	Epoch 28 complete! 	Average Loss:  0.06670891854991304
# 	Epoch 29 complete! 	Average Loss:  0.06666918866177823
# 	Epoch 30 complete! 	Average Loss:  0.06673058426760613
# 	Epoch 31 complete! 	Average Loss:  0.06666041352647416
# 	Epoch 32 complete! 	Average Loss:  0.06665508629793816
# 	Epoch 33 complete! 	Average Loss:  0.06704130984367208
# 	Epoch 34 complete! 	Average Loss:  0.06649417674287837
# 	Epoch 35 complete! 	Average Loss:  0.06649514566710654
# 	Epoch 36 complete! 	Average Loss:  0.06650013996565596
# 	Epoch 37 complete! 	Average Loss:  0.06652735931442139
# 	Epoch 38 complete! 	Average Loss:  0.06670307758006644
# 	Epoch 39 complete! 	Average Loss:  0.06655041125226528
# 	Epoch 40 complete! 	Average Loss:  0.06691085984732242
# 	Epoch 41 complete! 	Average Loss:  0.06660838815126013
# 	Epoch 42 complete! 	Average Loss:  0.0664556159301007
# 	Epoch 43 complete! 	Average Loss:  0.06648175421547382
# 	Epoch 44 complete! 	Average Loss:  0.06649230896158421
# 	Epoch 45 complete! 	Average Loss:  0.06653512595815861
# 	Epoch 46 complete! 	Average Loss:  0.06654021806539373
# 	Epoch 47 complete! 	Average Loss:  0.06651036929576955
# 	Epoch 48 complete! 	Average Loss:  0.06651953515854288
# 	Epoch 49 complete! 	Average Loss:  0.06651038816000553
# 	Epoch 50 complete! 	Average Loss:  0.0664986660822909
# 	Epoch 51 complete! 	Average Loss:  0.06652492579627545
# 	Epoch 52 complete! 	Average Loss:  0.06653454135707085
# 	Epoch 53 complete! 	Average Loss:  0.06652433095460242
# 	Epoch 54 complete! 	Average Loss:  0.06652416834171782
# 	Epoch 55 complete! 	Average Loss:  0.06649201074813274
# 	Epoch 56 complete! 	Average Loss:  0.06672278845563848
# 	Epoch 57 complete! 	Average Loss:  0.06646284825624303
# 	Epoch 58 complete! 	Average Loss:  0.06647684482183862
# 	Epoch 59 complete! 	Average Loss:  0.06658471508863124
# 	Epoch 60 complete! 	Average Loss:  0.06660661678364936
# 	Epoch 61 complete! 	Average Loss:  0.0664767603607888
# 	Epoch 62 complete! 	Average Loss:  0.06648478961371361
# 	Epoch 63 complete! 	Average Loss:  0.06649168102031058
# 	Epoch 64 complete! 	Average Loss:  0.06651132851839066
# 	Epoch 65 complete! 	Average Loss:  0.06650765367010807
# 	Epoch 66 complete! 	Average Loss:  0.06651734735103364
# 	Epoch 67 complete! 	Average Loss:  0.06650432433853758
# 	Epoch 68 complete! 	Average Loss:  0.06649586621751176
# 	Epoch 69 complete! 	Average Loss:  0.06648269026203359
# 	Epoch 70 complete! 	Average Loss:  0.06664037685445015
# 	Epoch 71 complete! 	Average Loss:  0.06645028749678997
# 	Epoch 72 complete! 	Average Loss:  0.06662752425416987
# 	Epoch 73 complete! 	Average Loss:  0.06646293138569974
# 	Epoch 74 complete! 	Average Loss:  0.06653902495795108
# 	Epoch 75 complete! 	Average Loss:  0.06648426176385677
# 	Epoch 76 complete! 	Average Loss:  0.06669932819427328
# 	Epoch 77 complete! 	Average Loss:  0.06645714031889084
# 	Epoch 78 complete! 	Average Loss:  0.0664778268400659
# 	Epoch 79 complete! 	Average Loss:  0.06648538337743029
# 	Epoch 80 complete! 	Average Loss:  0.06664919792971713
# 	Epoch 81 complete! 	Average Loss:  0.06647393237403099
# 	Epoch 82 complete! 	Average Loss:  0.06648542624204717
# 	Epoch 83 complete! 	Average Loss:  0.06649501948280537
# 	Epoch 84 complete! 	Average Loss:  0.06652049983435489
# 	Epoch 85 complete! 	Average Loss:  0.06646097698744308
# 	Epoch 86 complete! 	Average Loss:  0.06668284132759622
# 	Epoch 87 complete! 	Average Loss:  0.06646513396755178
# 	Epoch 88 complete! 	Average Loss:  0.06645616216862456
# 	Epoch 89 complete! 	Average Loss:  0.0665200894500347
# 	Epoch 90 complete! 	Average Loss:  0.06646533281879222
# 	Epoch 91 complete! 	Average Loss:  0.06647204832827791
# 	Epoch 92 complete! 	Average Loss:  0.06649157677559142
# 	Epoch 93 complete! 	Average Loss:  0.06647732108831406
# 	Epoch 94 complete! 	Average Loss:  0.06656077117361921
# 	Epoch 95 complete! 	Average Loss:  0.06648551739276724
# 	Epoch 96 complete! 	Average Loss:  0.0665058840779548
# 	Epoch 97 complete! 	Average Loss:  0.0665199248080558
# 	Epoch 98 complete! 	Average Loss:  0.06647062203351488
# 	Epoch 99 complete! 	Average Loss:  0.06646160594326385
# 	Epoch 100 complete! 	Average Loss:  0.06647366427994789
# Finish!!

# %%
model.eval()

with torch.no_grad():
    for batch_idx, (x, _) in enumerate(test_loader):
        batch_size = x.size(0)
        x = x.view(batch_size, 784)
        x = x.to(device)

        _, _, _, _, x_hat = model(x)

        break

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=15, ncols=4, figsize=(10, 60))

for i in range(15):

    original_image = x[i].view(28, 28).cpu().numpy()
    reconstructed_image = x_hat[i].view(28, 28).cpu().numpy()

    axes[i, 0].imshow(original_image)
    axes[i, 0].set_title('Original Image')
    axes[i, 0].axis('off')

    axes[i, 1].imshow(reconstructed_image)
    axes[i, 1].set_title('Reconstructed Image')
    axes[i, 1].axis('off')
    j = i*2+1
    original_image = x[j].view(28, 28).cpu().numpy()
    reconstructed_image = x_hat[j].view(28, 28).cpu().numpy()

    # Add your own images or modify as per your requirement
    axes[i, 2].imshow(original_image)
    axes[i, 2].set_title('Original Image')
    axes[i, 2].axis('off')

    axes[i, 3].imshow(reconstructed_image)
    axes[i, 3].set_title('Reconstructed Image')
    axes[i, 3].axis('off')

plt.tight_layout()
plt.show()
