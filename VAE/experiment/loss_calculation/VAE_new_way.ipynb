# %%
import torch
import torch.nn as nn

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter('runs/vae_new_way')

# %%
device = torch.device("cpu")
# for nvidia gpu ( cuda backend )
if (torch.cuda.is_available()):
    device = torch.device("cuda")
  # mps for apple M GPU ( metal backend )
elif (torch.backends.mps.is_available()):
    device = torch.device("mps")

print("Using device:", device)
# Out:
# Using device: mps

# %%
lr = 1e-3
batch_size = 256
epochs = 100

# %%
from torchvision.datasets import MNIST
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

dataset_path = '../data'


mnist_transform = transforms.Compose([
    transforms.ToTensor(),
])

kwargs = {'num_workers': 1, 'pin_memory': True}

train_dataset = MNIST(
    dataset_path, transform=mnist_transform, train=True, download=True)
test_dataset = MNIST(dataset_path, transform=mnist_transform,
                     train=False, download=True)

train_loader = DataLoader(dataset=train_dataset,
                          batch_size=batch_size, shuffle=True, **kwargs)
test_loader = DataLoader(dataset=test_dataset,
                         batch_size=batch_size, shuffle=False, **kwargs)

# %%
import sys # nopep8
sys.path.append('../')  # nopep8
from model import VAE
# from annealing import Annealing




model = VAE(
    encoder= nn.Sequential(
        nn.Linear(784, 512),
        nn.ReLU(),
        nn.Linear(512,256),
        nn.ReLU(),
    ),
    decoder= nn.Sequential(
        nn.Linear(128, 256),
        nn.ReLU(),
        nn.Linear(256, 512),
        nn.ReLU(),
        nn.Linear(512, 784),
        nn.Sigmoid()
    ),
    mean= nn.Linear(256, 128),
    var= nn.Linear(256, 128)
).to(device)


# annealing = Annealing.frange_cycle_linear(0, 1, 100)
# Out:
# VAE model initialized

# %%
from torch.optim import Adam


def loss_function(x, x_hat, mean, log_var):
    # sum over pixels then div by the batch dim
    reproduction_loss = nn.functional.mse_loss(x_hat, x, reduction='none').sum(dim=1).mean()
    # sum over the dimensions of the latent space then div by the batch dim
    KLD = torch.mean(-0.5 * torch.sum(1 + log_var - mean **
                     2 - log_var.exp(), dim=1), dim=0)
    return reproduction_loss, KLD


optimizer = Adam(model.parameters(), lr=lr)

# %%
print("Start training VAE...")
model.train()

for epoch in range(epochs):
    overall_loss = 0
    overall_rec = 0
    overall_kl = 0
    for batch_idx, (x, _) in enumerate(train_loader):
        batch_size = x.size(0)
        x = x.view(batch_size, 784)
        x = x.to(device)
        optimizer.zero_grad()
        _, mean, log_var,_,x_hat = model(x)
        if batch_idx == 0:
            writer.add_images('input', x[0].view(
                1, 1, 28, 28), epoch+1)
            writer.add_images('reconstruction', x_hat[0].view(
                1, 1, 28, 28), epoch+1)
            
        loss_rec,loss_kld = loss_function(x, x_hat, mean, log_var)
        loss = loss_rec + 1*(loss_kld)
        overall_rec += loss_rec.item()
        overall_kl += loss_kld.item()
        overall_loss += loss.item()
        loss.backward()
        optimizer.step()

    writer.add_scalar('Loss/total', overall_loss / len(train_loader), epoch+1)
    writer.add_scalar('Loss/rec', overall_rec / len(train_loader), epoch+1)
    writer.add_scalar('Loss/kl', overall_kl / len(train_loader), epoch+1)
    print("\tEpoch", epoch + 1, "complete!", "\tAverage Loss: ",
          overall_loss / len(train_loader))

print("Finish!!")
# Out:
# Start training VAE...
# 	Epoch 1 complete! 	Average Loss:  54.24478323104534
# 	Epoch 2 complete! 	Average Loss:  46.59496627158307
# 	Epoch 3 complete! 	Average Loss:  41.55600975523604
# 	Epoch 4 complete! 	Average Loss:  36.61761783031707
# 	Epoch 5 complete! 	Average Loss:  34.266716530982485
# 	Epoch 6 complete! 	Average Loss:  32.97420909962756
# 	Epoch 7 complete! 	Average Loss:  32.15616460759589
# 	Epoch 8 complete! 	Average Loss:  31.65360598462693
# 	Epoch 9 complete! 	Average Loss:  31.265560288124895
# 	Epoch 10 complete! 	Average Loss:  30.938500010713618
# 	Epoch 11 complete! 	Average Loss:  30.665993759479928
# 	Epoch 63 complete! 	Average Loss:  27.05225344718771
# 	Epoch 64 complete! 	Average Loss:  26.98843854538938
# 	Epoch 65 complete! 	Average Loss:  27.004051151681452
# 	Epoch 66 complete! 	Average Loss:  26.973311006261948
# 	Epoch 67 complete! 	Average Loss:  26.967838173724235
# 	Epoch 68 complete! 	Average Loss:  26.95420450251153
# 	Epoch 69 complete! 	Average Loss:  26.93440901573668
# 	Epoch 70 complete! 	Average Loss:  26.93346584401232
# 	Epoch 71 complete! 	Average Loss:  26.918050238426694
# 	Epoch 72 complete! 	Average Loss:  26.91114611524217
# 	Epoch 73 complete! 	Average Loss:  26.891596181341942
# 	Epoch 74 complete! 	Average Loss:  26.882603763012177
# 	Epoch 75 complete! 	Average Loss:  26.860195849804168
# 	Epoch 76 complete! 	Average Loss:  26.86477607564723
# 	Epoch 77 complete! 	Average Loss:  26.842184569987843
# 	Epoch 78 complete! 	Average Loss:  26.823630734707447
# 	Epoch 79 complete! 	Average Loss:  26.79473253615359
# 	Epoch 80 complete! 	Average Loss:  26.79507453593802
# 	Epoch 81 complete! 	Average Loss:  26.81601182653549
# 	Epoch 82 complete! 	Average Loss:  26.808854391219768
# 	Epoch 83 complete! 	Average Loss:  26.77323089761937
# 	Epoch 84 complete! 	Average Loss:  26.789615152237264
# 	Epoch 85 complete! 	Average Loss:  26.78127895923371
# 	Epoch 86 complete! 	Average Loss:  26.76609478402645
# 	Epoch 87 complete! 	Average Loss:  26.749924517692403
# 	Epoch 88 complete! 	Average Loss:  26.73177879008841
# 	Epoch 89 complete! 	Average Loss:  26.727297689559613
# 	Epoch 90 complete! 	Average Loss:  26.713375383742314
# 	Epoch 91 complete! 	Average Loss:  26.71498580283307
# 	Epoch 92 complete! 	Average Loss:  26.689089438255795
# 	Epoch 93 complete! 	Average Loss:  26.6877359674332
# 	Epoch 94 complete! 	Average Loss:  26.680163103468875
# 	Epoch 95 complete! 	Average Loss:  26.7026984113328
# 	Epoch 96 complete! 	Average Loss:  26.65056263538117
# 	Epoch 97 complete! 	Average Loss:  26.64278469491512
# 	Epoch 98 complete! 	Average Loss:  26.642392373592294
# 	Epoch 99 complete! 	Average Loss:  26.65254080752109
# 	Epoch 100 complete! 	Average Loss:  26.611776911958735
# Finish!!

# %%
model.eval()

with torch.no_grad():
    for batch_idx, (x, _) in enumerate(test_loader):
        batch_size = x.size(0)
        x = x.view(batch_size, 784)
        x = x.to(device)

        _, _, _, _, x_hat = model(x)

        break

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=15, ncols=4, figsize=(10, 60))

for i in range(15):

    original_image = x[i].view(28, 28).cpu().numpy()
    reconstructed_image = x_hat[i].view(28, 28).cpu().numpy()

    axes[i, 0].imshow(original_image)
    axes[i, 0].set_title('Original Image')
    axes[i, 0].axis('off')

    axes[i, 1].imshow(reconstructed_image)
    axes[i, 1].set_title('Reconstructed Image')
    axes[i, 1].axis('off')
    j = i*2+1
    original_image = x[j].view(28, 28).cpu().numpy()
    reconstructed_image = x_hat[j].view(28, 28).cpu().numpy()

    # Add your own images or modify as per your requirement
    axes[i, 2].imshow(original_image)
    axes[i, 2].set_title('Original Image')
    axes[i, 2].axis('off')

    axes[i, 3].imshow(reconstructed_image)
    axes[i, 3].set_title('Reconstructed Image')
    axes[i, 3].axis('off')

plt.tight_layout()
plt.show()
